# %% [markdown]
# <a href="https://colab.research.google.com/github/DevShah2k4/Internship_Projects/blob/main/Crowd_Counting_Project_Training_Part.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 67.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !unzip /content/crowd_counting_dataset.v1i.yolov8.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/labels/img_224_jpg.rf.58f3376449d70f49fef004545003b583.txt
#   inflating: train/labels/img_224_jpg.rf.6d8893ce9da62a65e47ee2284b86bee2.txt
#   inflating: train/labels/img_224_jpg.rf.79ba307beb507b57b690644c930dd7ac.txt
#   inflating: train/labels/img_224_jpg.rf.7d44b628af8591336a5402461808fa3a.txt
#   inflating: train/labels/img_224_jpg.rf.8ba16b9c6c9dee5bdbb4d544c6c0161f.txt
#   inflating: train/labels/img_224_jpg.rf.a4375e0ca6896209042e699304854305.txt
#   inflating: train/labels/img_224_jpg.rf.ab172a7144672a080638b6d77ac3f76a.txt
#   inflating: train/labels/img_224_jpg.rf.c0a7ff13dcd36c850ad16d97ca01ef65.txt
#   inflating: train/labels/img_224_jpg.rf.cfc6bf5d9bef674a101024aa432bfb48.txt
#   inflating: train/labels/img_225_jpg.rf.5ee31de86a5e6d320096e7974788e73b.txt
#   inflating: train/labels/img_225_jpg.rf.88ab93abb88a00d9aca1edb0aa9aaa0e.txt
# ...

# %%
model = YOLO("yolov8n.pt")
model.train(data="/content/data.yaml",epochs=50,imgsz=640,batch=10,patience=5)
# Out:
# Ultralytics 8.4.30 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import os

for root, dirs, files in os.walk("runs"):
    for file in files:
        if file.endswith(".pt"):
            print(os.path.join(root, file))
# Out:
# runs/detect/train2/weights/best.pt
# runs/detect/train2/weights/last.pt

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train2/weights/best.pt")

metrics = model.val(data="data.yaml")

print("mAP50:", metrics.box.map50)
print("mAP50-95:", metrics.box.map)
print("Precision:", metrics.box.mp)
print("Recall:", metrics.box.mr)
# Out:
# Ultralytics 8.4.30 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 543.4±210.9 MB/s, size: 12.1 KB)
# val: Scanning /content/valid/labels.cache... 382 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 382/382 114.4Mit/s 0.0s
# val: /content/valid/images/img_398_jpg.rf.9f5230c10877b68e3133cec6f8876d05.jpg: 1 duplicate labels removed
# val: /content/valid/images/img_427_jpg.rf.59e632e846893e0525a02ea15af7694e.jpg: 1 duplicate labels removed
# val: /content/valid/images/img_469_jpg.rf.8c31fc86497266ae2ad42f112218cd35.jpg: 1 duplicate labels removed
# val: /content/valid/images/img_472_jpg.rf.129f967eb3054e7d33b204a69e5e168f.jpg: 5 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 1.3s/it 30.2s
# ...

# %%
from google.colab import files

files.download("runs/detect/train2/weights/best.pt")
